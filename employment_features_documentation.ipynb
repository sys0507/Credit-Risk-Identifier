# %% [raw]
# # Employment Data Enhancement Documentation
#
# ## Overview
# This documentation explains how we enhanced the credit risk dataset with employment-related features by crawling employment statistics from various authoritative sources.
#
# ## Data Sources
#
# ### 1. Bureau of Labor Statistics (BLS)
# - Official employment tenure statistics
# - Job turnover rates
# - Industry-specific employment trends
#
# ### 2. LinkedIn
# - Employee tenure trends
# - Industry-specific employment patterns
# - Job market analysis
#
# ### 3. Glassdoor
# - Employment duration statistics
# - Industry turnover rates
# - Job market trends
#
# ## New Features Added
#
# ### 1. Employment Length Risk Score (emp_length_risk_score)
# - **Range**: 0.1 to 0.9
# - **Interpretation**:
#   * 0.1: Very low risk (≥8 years)
#   * 0.3: Low risk (5-8 years)
#   * 0.5: Medium risk (3-5 years)
#   * 0.7: High risk (1-3 years)
#   * 0.9: Very high risk (<1 year)
#
# ### 2. Employment Length Ratio (emp_length_ratio)
# - **Definition**: Individual's employment length divided by industry average
# - **Interpretation**:
#   * >1.0: Above average tenure
#   * =1.0: Average tenure
#   * <1.0: Below average tenure
#
# ### 3. Turnover Risk Indicator (emp_turnover_risk)
# - **Values**: 0 or 1
# - **Definition**: Binary indicator for high turnover risk
# - **Criteria**: 1 if employment length < 1 year, 0 otherwise

# %% [raw]
# ## Implementation Details
#
# ### Data Collection Process
# 1. **Web Crawling**:
#    - Uses both static (requests) and dynamic (Selenium) crawling
#    - Implements rate limiting and user agent rotation
#    - Handles missing data with fallback values
#
# 2. **Data Extraction**:
#    - Regular expressions for consistent pattern matching
#    - Multiple patterns per metric to increase capture rate
#    - Aggregation of data from multiple sources
#
# 3. **Data Processing**:
#    - Median calculations for robust statistics
#    - Normalization of employment lengths
#    - Risk score calculation based on industry benchmarks
#
# ### Risk Score Calculation
# ```python
# def calculate_employment_risk_score(emp_length, stats):
#     if emp_length >= stats['risk_thresholds']['very_low']:    # ≥8 years
#         return 0.1
#     elif emp_length >= stats['risk_thresholds']['low']:       # ≥5 years
#         return 0.3
#     elif emp_length >= stats['risk_thresholds']['medium']:    # ≥3 years
#         return 0.5
#     elif emp_length >= stats['risk_thresholds']['high']:      # ≥1 year
#         return 0.7
#     else:                                                     # <1 year
#         return 0.9
# ```

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the enhanced dataset
df = pd.read_csv('credit-risk-dataset/employment_enhanced_dataset.csv')

# Create visualizations
plt.figure(figsize=(15, 10))

# Plot 1: Employment Length Risk Score Distribution
plt.subplot(2, 2, 1)
sns.histplot(data=df, x='emp_length_risk_score', bins=20)
plt.title('Distribution of Employment Length Risk Scores')
plt.xlabel('Risk Score')
plt.ylabel('Count')

# Plot 2: Employment Length Ratio Distribution
plt.subplot(2, 2, 2)
sns.histplot(data=df, x='emp_length_ratio', bins=20)
plt.title('Distribution of Employment Length Ratios')
plt.xlabel('Length Ratio (Individual/Average)')
plt.ylabel('Count')

# Plot 3: Turnover Risk by Loan Status
plt.subplot(2, 2, 3)
sns.barplot(data=df, x='turnover_risk', y='loan_status', estimator=lambda x: len(x[x==1])/len(x)*100)
plt.title('Default Rate by Turnover Risk')
plt.xlabel('Turnover Risk')
plt.ylabel('Default Rate (%)')

# Plot 4: Risk Score vs Loan Amount
plt.subplot(2, 2, 4)
sns.scatterplot(data=df, x='emp_length_risk_score', y='loan_amnt', alpha=0.5)
plt.title('Risk Score vs Loan Amount')
plt.xlabel('Employment Length Risk Score')
plt.ylabel('Loan Amount')

plt.tight_layout()
plt.show()

# Print summary statistics
print("\nSummary Statistics for New Features:")
print("\nEmployment Length Risk Score:")
print(df['emp_length_risk_score'].describe())
print("\nEmployment Length Ratio:")
print(df['emp_length_ratio'].describe())
print("\nTurnover Risk Distribution:")
print(df['emp_turnover_risk'].value_counts(normalize=True))
